# %%
base = 312.84
print(base/(5214/100))

print((base/6)*100)
print(((base+104.28)/8)*100)

out = 1119.07
pop = 5214

out = 2164.84
pop = 4184

unit = out / (pop / 100)
print(unit)

# mul = 1 + sum(v for v in modifier.values())
# print(mul)
# 8 * mul
# Out:
# base mult: 2.6799999999999997
# real_workforce: 5070.0
# res: 1087.008
# 5.999999999999999
# 5213.999999999999
# 5214.0
# 51.74091778202677

# %%
mult_modifier = {
    # 'stability': 0.103,
    'planet_jobs_produces_mult': 0.18,
    'planet_jobs_productive_produces_mult': 0,
    'planet_jobs_worker_produces_mult': 0.05,
    
    'planet_jobs_energy_produces_mult': 0,
    'planet_technician_produces_mult': 0.85,
    'planet_technician_energy_produces_mult': 0.6,
    
    'planet_jobs_simple_drone_produces_mult':0,
    'planet_jobs_complex_and_simple_drone_produces_mult':0,
    'habitat_jobs_produces_mult':0
}

base_mul = 1 + sum(v for v in mult_modifier.values())
print(f'base mult: {base_mul}')
workforce_bonus_mult = 0.3
base_unit = 8
pop = 3900
real_workforce = pop * (1+workforce_bonus_mult)
print(f'unit produce per 100 pop: {base_unit * base_mul}')
res = real_workforce / 100 * base_unit * base_mul
print(f'real_workforce: {real_workforce}')
print(f'res: {res}')
# Out:
# base mult: 2.6799999999999997
# unit produce per 100 pop: 21.439999999999998
# real_workforce: 5070.0
# res: 1087.008
